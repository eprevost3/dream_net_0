# %%
from tensorflow.keras.models import Model
import tensorflow.keras.backend as K
import tensorflow as tf 
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import numpy as np

# %%
inception = tf.keras.applications.InceptionV3(include_top=False, weights='imagenet')


input = inception.input
outputs = [layer.output for layer in inception.layers]
output = [outputs[100], outputs[164]]

model = Model(input, output)

# %%
def plot_img(image : np.ndarray, title : str = "",) :
    # make sure we have an image of the right size
    if len(image.shape) == 3 : img = image
    else : img = image[0, :, :, :]

    plt.figure(figsize = (15, 10))
    plt.title(title)
    plt.imshow(img)
    plt.show()
    
def get_grad(img, model) : 
    with tf.GradientTape() as tape : 
        tape.watch(img)
        
        # there may be more than one output layers
        preds = model(img)        

        losses = tf.concat([ [K.mean(pred)] for pred in preds], axis = 0)        
        tot_loss = K.sum(losses)
        
    grad = tape.gradient(tot_loss, img)
    
    grad /= K.std(grad) + 1e-8 
    
    return grad

   
def deep_dream(img, nb_iterations : int, plot_every : int, model, lr : float = 1,) : 
    # img : tensor
    for k in range(nb_iterations) :
        grad = get_grad(img, model)        
        img += lr * grad
        
        img = tf.clip_by_value(img, 0, 1)
        if k % plot_every == 0: 
            print("iteration", k)
            plot_img(img.numpy())
    
    return img

# path to the image, either png or jpeg
PATH = "luffy.jpg"

if "png" not in PATH : new_image = mpimg.imread(PATH)
else : new_image = mpimg.imread(PATH)[:, :, : 3]
    
plot_img(new_image,)

# %%
if "png" not in PATH : img = mpimg.imread(PATH) / 255
else : img = mpimg.imread(PATH)[:, :, : 3]
    
tf_img = tf.convert_to_tensor(img, dtype = tf.float32)

# reshape image to get 4 dimensions 
curr_shape = tf.shape(tf_img).numpy()
new_shape = np.insert(curr_shape, 0, 1)

tf_img = tf.reshape(tf_img, new_shape)

# let's use a smaller resolution for faster results
#new_shape[1], new_shape[2] = int(new_shape[1] / 2), int(new_shape[2] / 2) 
#tf_img = tf.image.resize(tf_img, new_shape[1 : 3])

plot_img(tf_img.numpy()[0, :, :, :])

# variable shape of the image 
shape = new_shape.copy()
for k in [1, 1.5, 2, 2.5, 3] : 
    shape[1 : 3] = new_shape[1 : 3] * k
    
    # get back to shape expressed in integers
    shape = np.array(shape, dtype = int)
    resized_img = tf.image.resize(tf_img, shape[1 : 3])
    tf_img = deep_dream(resized_img, 100, 10, model, lr = .01)
    
# resize image to original size 
tf_img = tf.image.resize(tf_img, new_shape[1 : 3])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-141-cf46683428a7> in <module>
#      24     shape = np.array(shape, dtype = int)
#      25     resized_img = tf.image.resize(tf_img, shape[1 : 3])
# ---> 26     tf_img = deep_dream(resized_img, 100, 10, model, lr = .01)
#      27
#      28 # resize image to original size
#
# <ipython-input-139-79f4a3484d08> in deep_dream(img, nb_iterations, plot_every, model, lr)
#      29     # img : tensor
#      30     for k in range(nb_iterations) :
# ---> 31         grad = get_grad(img, model)
#      32         img += lr * grad
#      33
#
# <ipython-input-139-79f4a3484d08> in get_grad(img, model)
#      19         tot_loss = K.sum(losses)
#      20
# ---> 21     grad = tape.gradient(tot_loss, img)
#      22
#      23     grad /= K.std(grad) + 1e-8
#
# c:\programdata\miniconda3\lib\site-packages\tensorflow_core\python\eager\backprop.py in gradient(self, target, sources, output_gradients, unconnected_gradients)
#    1027         output_gradients=output_gradients,
#    1028         sources_raw=flat_sources_raw,
# -> 1029         unconnected_gradients=unconnected_gradients)
#    1030
#    1031     if not self._persistent:
#
# c:\programdata\miniconda3\lib\site-packages\tensorflow_core\python\eager\imperative_grad.py in imperative_grad(tape, target, sources, output_gradients, sources_raw, unconnected_gradients)
#      75       output_gradients,
#      76       sources_raw,
# ---> 77       compat.as_str(unconnected_gradients.value))
#
# c:\programdata\miniconda3\lib\site-packages\tensorflow_core\python\eager\backprop.py in _gradient_function(op_name, attr_tuple, num_inputs, inputs, outputs, out_grads, skip_input_indices)
#     139     return [None] * num_inputs
#     140
# --> 141   return grad_fn(mock_op, *out_grads)
#     142
#     143
#
# c:\programdata\miniconda3\lib\site-packages\tensorflow_core\python\ops\nn_grad.py in _Conv2DGrad(op, grad)
#     604           explicit_paddings=explicit_paddings,
#     605           use_cudnn_on_gpu=use_cudnn_on_gpu,
# --> 606           data_format=data_format)
#     607   ]
#     608
#
# c:\programdata\miniconda3\lib\site-packages\tensorflow_core\python\ops\gen_nn_ops.py in conv2d_backprop_filter(input, filter_sizes, out_backprop, strides, padding, use_cudnn_on_gpu, explicit_paddings, data_format, dilations, name)
#    1079         strides, "use_cudnn_on_gpu", use_cudnn_on_gpu, "padding", padding,
#    1080         "explicit_paddings", explicit_paddings, "data_format", data_format,
# -> 1081         "dilations", dilations)
#    1082       return _result
#    1083     except _core._FallbackException:
#
# KeyboardInterrupt:

# %%
for k, layer in enumerate(base_model.layers) : 
    print(k, layer.name)
# Out:
# 0 input_4
# 1 conv2d_282
# 2 batch_normalization_282
# 3 activation_282
# 4 conv2d_283
# 5 batch_normalization_283
# 6 activation_283
# 7 conv2d_284
# 8 batch_normalization_284
# 9 activation_284
# 10 max_pooling2d_12
# 11 conv2d_285
# 12 batch_normalization_285
# 13 activation_285
# 14 conv2d_286
# 15 batch_normalization_286
# 16 activation_286
# 17 max_pooling2d_13
# 18 conv2d_290
# 19 batch_normalization_290
# 20 activation_290
# 21 conv2d_288
# 22 conv2d_291
# 23 batch_normalization_288
# 24 batch_normalization_291
# 25 activation_288
# 26 activation_291
# 27 average_pooling2d_27
# 28 conv2d_287
# 29 conv2d_289
# 30 conv2d_292
# 31 conv2d_293
# 32 batch_normalization_287
# 33 batch_normalization_289
# 34 batch_normalization_292
# 35 batch_normalization_293
# 36 activation_287
# 37 activation_289
# 38 activation_292
# 39 activation_293
# 40 mixed0
# 41 conv2d_297
# 42 batch_normalization_297
# 43 activation_297
# 44 conv2d_295
# 45 conv2d_298
# 46 batch_normalization_295
# 47 batch_normalization_298
# 48 activation_295
# 49 activation_298
# 50 average_pooling2d_28
# 51 conv2d_294
# 52 conv2d_296
# 53 conv2d_299
# 54 conv2d_300
# 55 batch_normalization_294
# 56 batch_normalization_296
# 57 batch_normalization_299
# 58 batch_normalization_300
# 59 activation_294
# 60 activation_296
# 61 activation_299
# 62 activation_300
# 63 mixed1
# 64 conv2d_304
# 65 batch_normalization_304
# 66 activation_304
# 67 conv2d_302
# 68 conv2d_305
# 69 batch_normalization_302
# 70 batch_normalization_305
# 71 activation_302
# 72 activation_305
# 73 average_pooling2d_29
# 74 conv2d_301
# 75 conv2d_303
# 76 conv2d_306
# 77 conv2d_307
# 78 batch_normalization_301
# 79 batch_normalization_303
# 80 batch_normalization_306
# 81 batch_normalization_307
# 82 activation_301
# 83 activation_303
# 84 activation_306
# 85 activation_307
# 86 mixed2
# 87 conv2d_309
# 88 batch_normalization_309
# 89 activation_309
# 90 conv2d_310
# 91 batch_normalization_310
# 92 activation_310
# 93 conv2d_308
# 94 conv2d_311
# 95 batch_normalization_308
# 96 batch_normalization_311
# 97 activation_308
# 98 activation_311
# 99 max_pooling2d_14
# 100 mixed3
# 101 conv2d_316
# 102 batch_normalization_316
# 103 activation_316
# 104 conv2d_317
# 105 batch_normalization_317
# 106 activation_317
# 107 conv2d_313
# 108 conv2d_318
# 109 batch_normalization_313
# 110 batch_normalization_318
# 111 activation_313
# 112 activation_318
# 113 conv2d_314
# 114 conv2d_319
# 115 batch_normalization_314
# 116 batch_normalization_319
# 117 activation_314
# 118 activation_319
# 119 average_pooling2d_30
# 120 conv2d_312
# 121 conv2d_315
# 122 conv2d_320
# 123 conv2d_321
# 124 batch_normalization_312
# 125 batch_normalization_315
# 126 batch_normalization_320
# 127 batch_normalization_321
# 128 activation_312
# 129 activation_315
# 130 activation_320
# 131 activation_321
# 132 mixed4
# 133 conv2d_326
# 134 batch_normalization_326
# 135 activation_326
# 136 conv2d_327
# 137 batch_normalization_327
# 138 activation_327
# 139 conv2d_323
# 140 conv2d_328
# 141 batch_normalization_323
# 142 batch_normalization_328
# 143 activation_323
# 144 activation_328
# 145 conv2d_324
# 146 conv2d_329
# 147 batch_normalization_324
# 148 batch_normalization_329
# 149 activation_324
# 150 activation_329
# 151 average_pooling2d_31
# 152 conv2d_322
# 153 conv2d_325
# 154 conv2d_330
# 155 conv2d_331
# 156 batch_normalization_322
# 157 batch_normalization_325
# 158 batch_normalization_330
# 159 batch_normalization_331
# 160 activation_322
# 161 activation_325
# 162 activation_330
# 163 activation_331
# 164 mixed5
# 165 conv2d_336
# 166 batch_normalization_336
# 167 activation_336
# 168 conv2d_337
# 169 batch_normalization_337
# 170 activation_337
# 171 conv2d_333
# 172 conv2d_338
# 173 batch_normalization_333
# 174 batch_normalization_338
# 175 activation_333
# 176 activation_338
# 177 conv2d_334
# 178 conv2d_339
# 179 batch_normalization_334
# 180 batch_normalization_339
# 181 activation_334
# 182 activation_339
# 183 average_pooling2d_32
# 184 conv2d_332
# 185 conv2d_335
# 186 conv2d_340
# 187 conv2d_341
# 188 batch_normalization_332
# 189 batch_normalization_335
# 190 batch_normalization_340
# 191 batch_normalization_341
# 192 activation_332
# 193 activation_335
# 194 activation_340
# 195 activation_341
# 196 mixed6
# 197 conv2d_346
# 198 batch_normalization_346
# 199 activation_346
# 200 conv2d_347
# 201 batch_normalization_347
# 202 activation_347
# 203 conv2d_343
# 204 conv2d_348
# 205 batch_normalization_343
# 206 batch_normalization_348
# 207 activation_343
# 208 activation_348
# 209 conv2d_344
# 210 conv2d_349
# 211 batch_normalization_344
# 212 batch_normalization_349
# 213 activation_344
# 214 activation_349
# 215 average_pooling2d_33
# 216 conv2d_342
# 217 conv2d_345
# 218 conv2d_350
# 219 conv2d_351
# 220 batch_normalization_342
# 221 batch_normalization_345
# 222 batch_normalization_350
# 223 batch_normalization_351
# 224 activation_342
# 225 activation_345
# 226 activation_350
# 227 activation_351
# 228 mixed7
# 229 conv2d_354
# 230 batch_normalization_354
# 231 activation_354
# 232 conv2d_355
# 233 batch_normalization_355
# 234 activation_355
# 235 conv2d_352
# 236 conv2d_356
# 237 batch_normalization_352
# 238 batch_normalization_356
# 239 activation_352
# 240 activation_356
# 241 conv2d_353
# 242 conv2d_357
# 243 batch_normalization_353
# 244 batch_normalization_357
# 245 activation_353
# 246 activation_357
# 247 max_pooling2d_15
# 248 mixed8
# 249 conv2d_362
# 250 batch_normalization_362
# 251 activation_362
# 252 conv2d_359
# 253 conv2d_363
# 254 batch_normalization_359
# 255 batch_normalization_363
# 256 activation_359
# 257 activation_363
# 258 conv2d_360
# 259 conv2d_361
# 260 conv2d_364
# 261 conv2d_365
# 262 average_pooling2d_34
# 263 conv2d_358
# 264 batch_normalization_360
# 265 batch_normalization_361
# 266 batch_normalization_364
# 267 batch_normalization_365
# 268 conv2d_366
# 269 batch_normalization_358
# 270 activation_360
# 271 activation_361
# 272 activation_364
# 273 activation_365
# 274 batch_normalization_366
# 275 activation_358
# 276 mixed9_0
# 277 concatenate_6
# 278 activation_366
# 279 mixed9
# 280 conv2d_371
# 281 batch_normalization_371
# 282 activation_371
# 283 conv2d_368
# 284 conv2d_372
# 285 batch_normalization_368
# 286 batch_normalization_372
# 287 activation_368
# 288 activation_372
# 289 conv2d_369
# 290 conv2d_370
# 291 conv2d_373
# 292 conv2d_374
# 293 average_pooling2d_35
# 294 conv2d_367
# 295 batch_normalization_369
# 296 batch_normalization_370
# 297 batch_normalization_373
# 298 batch_normalization_374
# 299 conv2d_375
# 300 batch_normalization_367
# 301 activation_369
# 302 activation_370
# 303 activation_373
# 304 activation_374
# 305 batch_normalization_375
# 306 activation_367
# 307 mixed9_1
# 308 concatenate_7
# 309 activation_375
# 310 mixed10
